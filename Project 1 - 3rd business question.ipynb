# %%
#Which neighborhoods in Boston have the highest rental prices?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from matplotlib import pyplot as plt
# %matplotlib inline

df = pd.read_csv('./Boston-listings.csv')
# df.head()
pd.set_option('display.max_rows', None)
df = df[['host_neighbourhood', 'property_type','price']]
df.dropna(subset=['host_neighbourhood'],inplace=True)

df['price']=df['price'].str.replace('[$,]', '')
df['price']=df['price'].astype(float)

df = df.groupby(['host_neighbourhood']).mean().reset_index()
df = df.sort_values(by=['price'],ascending=False)
print(df)
# df = df[df['price'] > 180]
# print(df[['price']].max())
# df.plot.bar('host_neighbourhood', 'price', figsize=(25, 10))
# print(df)
print(df['price'].mean())
print(df['price'].min())
print(df['price'].max())

fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)

chart = sn.barplot(x="host_neighbourhood",y="price",ax=ax,data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()
# Out:
# /var/folders/nh/b503281s5qj68mghqwwb6xlw0000gn/T/ipykernel_72509/239956689.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price']=df['price'].str.replace('[$,]', '')
#            host_neighbourhood       price
# 5              Bernal Heights  375.000000
# 47                  Sunnyvale  365.000000
# 10                    Chelsea  340.000000
# 50                   West End  298.841463
# 21         Financial District  298.769231
# 17          Downtown Crossing  271.303030
# 49            Upper East Side  269.307692
# 1                    Back Bay  261.205128
# 24          Government Center  250.000000
# 14                  Coral Way  249.000000
# 28           Leather District  245.875000
# 25             Harvard Square  235.000000
# 44               South Boston  229.484848
# 37                     Newton  225.000000
# 23                Gay Village  218.120690
# 48           Theater District  217.269231
# 20             Fenway/Kenmore  215.210345
# 9                 Charlestown  213.476923
# 45                  South End  211.643777
# 32                    Medford  210.700000
# 22          Flatiron District  209.000000
# 43                South Beach  204.250000
# 33                Miami Beach  200.000000
# 3                    Belváros  199.500000
# 12                  Chinatown  194.384615
# 38                  North End  194.341270
# 2                 Beacon Hill  194.201031
# 7                   Cambridge  193.862745
# 16                   Downtown  193.000000
# 4                 Benton Park  192.000000
# 52                   Winthrop  175.000000
# 8   Central Business District  156.480000
# 40                    Roxbury  147.853147
# 27              Jamaica Plain  139.981191
# 13            Coolidge Corner  126.000000
# 18                East Boston  121.359649
# 30                     Malden  115.000000
# 0            Allston-Brighton  111.506667
# 42                 Somerville  110.125000
# 51               West Roxbury  109.875000
# 36               Mission Hill  106.208333
# 29            Los Altos Hills  102.666667
# 41                 Santa Cruz  100.000000
# 34               Midtown East  100.000000
# 39                 Roslindale   98.603774
# 15                 Dorchester   93.665138
# 46            South of Nevsky   90.000000
# 26                  Hyde Park   87.612903
# 6                   Brookline   77.625000
# 35           Mission District   70.000000
# 31                   Mattapan   68.840000
# 11              Chestnut Hill   64.333333
# 19                East Harlem   62.500000
# 181.32043059458843
# 62.5
# 375.0

# %%
df = pd.read_csv('./Boston-listings.csv')
df = df[['host_neighbourhood', 'property_type', 'price']]
df.dropna(subset=['host_neighbourhood'],inplace=True)
df = df.groupby(['host_neighbourhood', 'property_type']).count()
print(df)
# Out:
#                                            price
# host_neighbourhood        property_type
# Allston-Brighton          Apartment          244
#                           Bed & Breakfast      1
#                           Condominium         11
#                           Dorm                 1
#                           House              107
#                           Loft                 2
#                           Other                1
#                           Townhouse            6
#                           Villa                1
# Back Bay                  Apartment          273
#                           Condominium         20
#                           House                7
#                           Loft                 4
#                           Other                6
#                           Townhouse            2
# Beacon Hill               Apartment          175
#                           Bed & Breakfast      3
#                           Condominium         11
#                           House                3
#                           Townhouse            2
# Belváros                  Apartment            2
# Benton Park               Apartment            1
# Bernal Heights            House                1
# Brookline                 Apartment            7
#                           Condominium          1
# Cambridge                 Apartment           40
#                           Condominium          5
#                           House                3
#                           Townhouse            3
# Central Business District Apartment           25
# Charlestown               Apartment           32
#                           Bed & Breakfast      3
#                           Condominium         13
#                           House               14
#                           Townhouse            3
# Chelsea                   Apartment            1
#                           Condominium          1
# Chestnut Hill             Apartment            1
#                           Townhouse            2
# Chinatown                 Apartment           10
#                           Condominium          1
#                           Loft                 2
# Coolidge Corner           Apartment            2
# Coral Way                 Apartment            1
# Dorchester                Apartment          130
#                           Bed & Breakfast      5
#                           Condominium         12
#                           Entire Floor         1
#                           House               65
#                           Loft                 1
#                           Townhouse            4
# Downtown                  Apartment            9
#                           Bed & Breakfast      1
#                           Condominium          1
#                           Villa                1
# Downtown Crossing         Apartment           31
#                           Loft                 1
# East Boston               Apartment           77
#                           Boat                 5
#                           Condominium          9
#                           House               21
#                           Townhouse            2
# East Harlem               Apartment            2
# Fenway/Kenmore            Apartment          281
#                           Condominium          7
#                           House                2
# Financial District        Apartment            6
#                           Condominium          1
#                           Other                3
#                           Villa                3
# Flatiron District         Apartment            3
# Gay Village               Apartment           39
#                           Condominium         15
#                           Loft                 3
# Government Center         Apartment            1
# Harvard Square            Apartment            2
# Hyde Park                 Apartment            9
#                           House               21
#                           Loft                 1
# Jamaica Plain             Apartment          174
#                           Bed & Breakfast     10
#                           Condominium         28
#                           Entire Floor         1
#                           Guesthouse           1
#                           House               93
#                           Loft                 2
#                           Townhouse           10
# Leather District          Apartment            3
#                           Condominium          3
#                           Loft                 2
# Los Altos Hills           Condominium          3
# Malden                    Apartment            1
# Mattapan                  Apartment            7
#                           House               15
#                           Loft                 1
#                           Townhouse            2
# Medford                   Apartment           12
#                           Bed & Breakfast      4
#                           Condominium          2
#                           Townhouse            2
# Miami Beach               Apartment            1
# Midtown East              Apartment            1
# Mission District          Apartment            1
# Mission Hill              Apartment           71
#                           Condominium          5
#                           House               14
#                           Loft                 5
#                           Townhouse            1
# Newton                    Apartment            1
# North End                 Apartment          106
#                           Boat                 6
#                           Condominium          4
#                           House                5
#                           Loft                 3
#                           Townhouse            2
# Roslindale                Apartment           17
#                           Condominium          5
#                           House               30
#                           Villa                1
# Roxbury                   Apartment           95
#                           Bed & Breakfast      2
#                           Condominium          2
#                           Entire Floor         1
#                           House               37
#                           Other                4
#                           Townhouse            2
# Santa Cruz                Apartment            1
# Somerville                Apartment           19
#                           Condominium          1
#                           Entire Floor         1
#                           House                3
# South Beach               Apartment            4
# South Boston              Apartment          126
#                           Condominium         30
#                           House               34
#                           Loft                 5
#                           Townhouse            3
# South End                 Apartment          184
#                           Bed & Breakfast      6
#                           Condominium         19
#                           Dorm                 1
#                           House               11
#                           Loft                 4
#                           Other                2
#                           Townhouse            6
# South of Nevsky           Apartment            1
# Sunnyvale                 Apartment            1
# Theater District          Apartment           21
#                           Bed & Breakfast      3
#                           House                1
#                           Loft                 1
# Upper East Side           Apartment           13
# West End                  Apartment           81
#                           Condominium          1
# West Roxbury              Apartment            5
#                           House               27
# Winthrop                  Apartment            1

# %%
df = pd.read_csv('./Boston-listings.csv')
print(df['host_neighbourhood'].nunique())
# Out:
# 53

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from matplotlib import pyplot as plt
# %matplotlib inline

df = pd.read_csv('./Boston-listings.csv')
pd.set_option('display.max_rows', None)
df = df[['host_neighbourhood', 'property_type','price']]
df.dropna(subset=['host_neighbourhood'],inplace=True)

df['price']=df['price'].str.replace('[$,]', '')
df['price']=df['price'].astype(float)
df = df.groupby(['host_neighbourhood']).mean().reset_index()
df = df.sort_values(by=['price'],ascending=False)

size = df.shape[0]

print(df[df['price']<150.0].shape[0] / size)
print((df[df['price'].between(150, 250)].shape[0] / size))
print(df[df['price']>250].shape[0] / df.shape[0])
# Out:
# 0.39622641509433965
# 0.4528301886792453
# 0.1509433962264151
# /var/folders/nh/b503281s5qj68mghqwwb6xlw0000gn/T/ipykernel_72509/656432973.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price']=df['price'].str.replace('[$,]', '')
